# %%
import pandas as pd
import numpy as np
from pandas import ExcelWriter
from pandas import DataFrame

# %%
df = pd.read_excel (r'C:\Users\nasirib2\OneDrive - Aalto University\Original data, building material.xlsx')
df.tail(20)
# Out:
#     Building and dwelling production by Construction stage, Province 2019, Building characteristic, Period, Intended use of building and Data  \
# 140                                                NaN
# 141                                                NaN
# 142                                                NaN
# 143                                                NaN
# 144                                     Latest update:
# 145                                                NaN
# 146                                            Source:
# 147                                                NaN
# 148                                           Contact:
# 149                                      Tilastokeskus
# 150  <A HREF=http://www.stat.fi/tup/rakennettuympar...
# 151                                                NaN
# 152                                                NaN
# 153                                          Copyright
# ...

# %%
# Number of rows to drop
n = 16
  
# Dropping last n rows using drop
df.drop(df.tail(n).index,
        inplace = True)
df.head()
# Out:
#   Building and dwelling production by Construction stage, Province 2019, Building characteristic, Period, Intended use of building and Data  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                               Building completions
#
#   Unnamed: 1                   Unnamed: 2             Unnamed: 3  Unnamed: 4  \
# 0        NaN                          NaN                    NaN         NaN
# 1        NaN                          NaN  Year of construction          NaN
# 2        NaN                          NaN                    NaN         NaN
# 3    1000000                          NaN                    NaN         NaN
# 4    1000000  Building material, Concrete                   1995         NaN
#
#               Unnamed: 5  Unnamed: 6             Unnamed: 7  Unnamed: 8  \
# ...

# %%
df= df.drop(['Building and dwelling production by Construction stage, Province 2019, Building characteristic, Period, Intended use of building and Data', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 4', 'Unnamed: 6', 'Unnamed: 8', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24','Unnamed: 25', 'Unnamed: 26'], axis= 1)
df.head(100)
# Out:
#                Unnamed: 3             Unnamed: 5             Unnamed: 7  \
# 0                     NaN                    NaN                    NaN
# 1   Year of construction         Wooden building                    NaN
# 2                     NaN  Residential buildings        Detached houses
# 3                     NaN  Gross Floor area (m2)  Gross Floor area (m2)
# 4                    1995                1170094                  85891
# ..                    ...                    ...                    ...
# 95                   2017                  24862                  10741
# 96                   1995                    896                    362
# 97                   1996                    384                    384
# 98                   1997                    209                    209
# 99                   1998                    192                    175
#
#                Unnamed: 9            Unnamed: 10  \
# 0                     NaN                    NaN
# ...

# %%
df = df.drop(df.index[range(4, 121)])
df
# Out:
#                 Unnamed: 3             Unnamed: 5             Unnamed: 7  \
# 0                      NaN                    NaN                    NaN
# 1    Year of construction         Wooden building                    NaN
# 2                      NaN  Residential buildings        Detached houses
# 3                      NaN  Gross Floor area (m2)  Gross Floor area (m2)
# 121                   1995                1535633                1306540
# 122                   1996                1431577                1185993
# 123                   1997                1712180                1398407
# 124                   1998                1954483                1581016
# 125                   1999                2052532                1722435
# 126                   2000                2235371                1858874
# 127                   2001                2102501                1798687
# 128                   2002                2029522                1793070
# ...

# %%
df= df.drop([df.index[3]])
df
# Out:
#                 Unnamed: 3             Unnamed: 5       Unnamed: 7  \
# 0                      NaN                    NaN              NaN
# 1    Year of construction         Wooden building              NaN
# 2                      NaN  Residential buildings  Detached houses
# 121                   1995                1535633          1306540
# 122                   1996                1431577          1185993
# 123                   1997                1712180          1398407
# 124                   1998                1954483          1581016
# 125                   1999                2052532          1722435
# 126                   2000                2235371          1858874
# 127                   2001                2102501          1798687
# 128                   2002                2029522          1793070
# 129                   2003                2158149          1853159
# 130                   2004                2498251          2186282
# ...

# %%
df= df.fillna(axis=1, method='ffill')
df
# Out:
#                 Unnamed: 3             Unnamed: 5       Unnamed: 7  \
# 0                      NaN                    NaN              NaN
# 1    Year of construction         Wooden building  Wooden building
# 2                      NaN  Residential buildings  Detached houses
# 121                   1995                1535633          1306540
# 122                   1996                1431577          1185993
# 123                   1997                1712180          1398407
# 124                   1998                1954483          1581016
# 125                   1999                2052532          1722435
# 126                   2000                2235371          1858874
# 127                   2001                2102501          1798687
# 128                   2002                2029522          1793070
# 129                   2003                2158149          1853159
# 130                   2004                2498251          2186282
# ...

# %%
df= df.drop(['Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 17'], axis= 1)
df.head()
# Out:
#                 Unnamed: 3             Unnamed: 5       Unnamed: 7  \
# 0                      NaN                    NaN              NaN
# 1    Year of construction         Wooden building  Wooden building
# 2                      NaN  Residential buildings  Detached houses
# 121                   1995                1535633          1306540
# 122                   1996                1431577          1185993
#
#           Unnamed: 9      Unnamed: 10                 Unnamed: 16  \
# 0                NaN              NaN                         NaN
# 1    Wooden building  Wooden building             Wooden building
# 2    Attached houses  Blocks of flats  Non-residential buildings
# 121           207700            21393                     1486828
# 122           225757            19827                     1514347
#
#                Unnamed: 18           Unnamed: 19           Unnamed: 20  \
# 0                      NaN                   NaN                   NaN
# ...

# %%
df = df.drop([df.index[0]])
df
# Out:
#                 Unnamed: 3             Unnamed: 5       Unnamed: 7  \
# 1    Year of construction         Wooden building  Wooden building
# 2                      NaN  Residential buildings  Detached houses
# 121                   1995                1535633          1306540
# 122                   1996                1431577          1185993
# 123                   1997                1712180          1398407
# 124                   1998                1954483          1581016
# 125                   1999                2052532          1722435
# 126                   2000                2235371          1858874
# 127                   2001                2102501          1798687
# 128                   2002                2029522          1793070
# 129                   2003                2158149          1853159
# 130                   2004                2498251          2186282
# 131                   2005                2646422          2289884
# ...

# %%
df= df.transpose()
df
# Out:
#                                1                           2        121  \
# Unnamed: 3   Year of construction                          NaN     1995
# Unnamed: 5         Wooden building       Residential buildings  1535633
# Unnamed: 7         Wooden building             Detached houses  1306540
# Unnamed: 9         Wooden building             Attached houses   207700
# Unnamed: 10        Wooden building             Blocks of flats    21393
# Unnamed: 16        Wooden building  Non-residential buildings   1486828
# Unnamed: 18   Non-wooden buildings       Residential buildings  1248319
# Unnamed: 19   Non-wooden buildings             Detached houses   149033
# Unnamed: 20   Non-wooden buildings             Attached houses   115110
# Unnamed: 21   Non-wooden buildings             Blocks of flats   984176
# Unnamed: 27   Non-wooden buildings  Non-residential buildings    901244
#
#                  122      123      124      125      126      127      128  \
# ...

# %%
df.columns = df.iloc[0]
df.head()
# Out:
# Unnamed: 3   Year of construction                     NaN     1995     1996  \
# Unnamed: 3   Year of construction                     NaN     1995     1996
# Unnamed: 5         Wooden building  Residential buildings  1535633  1431577
# Unnamed: 7         Wooden building        Detached houses  1306540  1185993
# Unnamed: 9         Wooden building        Attached houses   207700   225757
# Unnamed: 10        Wooden building        Blocks of flats    21393    19827
#
# Unnamed: 3      1997     1998     1999     2000     2001     2002  ...  \
# Unnamed: 3      1997     1998     1999     2000     2001     2002  ...
# Unnamed: 5   1712180  1954483  2052532  2235371  2102501  2029522  ...
# Unnamed: 7   1398407  1581016  1722435  1858874  1798687  1793070  ...
# Unnamed: 9    287978   337246   297534   340249   278123   219491  ...
# Unnamed: 10    25795    36221    32563    36248    25691    16961  ...
#
# Unnamed: 3      2008     2009     2010     2011     2012     2013     2014  \
# ...

# %%
df= df.drop(['Unnamed: 3'])
df
# Out:
# Unnamed: 3  Year of construction                          NaN     1995  \
# Unnamed: 5        Wooden building       Residential buildings  1535633
# Unnamed: 7        Wooden building             Detached houses  1306540
# Unnamed: 9        Wooden building             Attached houses   207700
# Unnamed: 10       Wooden building             Blocks of flats    21393
# Unnamed: 16       Wooden building  Non-residential buildings   1486828
# Unnamed: 18  Non-wooden buildings       Residential buildings  1248319
# Unnamed: 19  Non-wooden buildings             Detached houses   149033
# Unnamed: 20  Non-wooden buildings             Attached houses   115110
# Unnamed: 21  Non-wooden buildings             Blocks of flats   984176
# Unnamed: 27  Non-wooden buildings  Non-residential buildings    901244
#
# Unnamed: 3      1996     1997     1998     1999     2000     2001     2002  \
# Unnamed: 5   1431577  1712180  1954483  2052532  2235371  2102501  2029522
# ...

# %%
df.columns
# Out:
# Index(['Year of construction ',                     nan,
#                         '1995',                  '1996',
#                         '1997',                  '1998',
#                         '1999',                  '2000',
#                         '2001',                  '2002',
#                         '2003',                  '2004',
#                         '2005',                  '2006',
#                         '2007',                  '2008',
#                         '2009',                  '2010',
#                         '2011',                  '2012',
#                         '2013',                  '2014',
#                         '2015',                  '2016',
#                         '2017'],
#       dtype='object', name='Unnamed: 3')

# %%
df = df.rename(columns = {'Year of construction ': 'building material', np.nan: 'Building type'}, inplace = False)
df
# Out:
# Unnamed: 3      building material               Building type     1995  \
# Unnamed: 5        Wooden building       Residential buildings  1535633
# Unnamed: 7        Wooden building             Detached houses  1306540
# Unnamed: 9        Wooden building             Attached houses   207700
# Unnamed: 10       Wooden building             Blocks of flats    21393
# Unnamed: 16       Wooden building  Non-residential buildings   1486828
# Unnamed: 18  Non-wooden buildings       Residential buildings  1248319
# Unnamed: 19  Non-wooden buildings             Detached houses   149033
# Unnamed: 20  Non-wooden buildings             Attached houses   115110
# Unnamed: 21  Non-wooden buildings             Blocks of flats   984176
# Unnamed: 27  Non-wooden buildings  Non-residential buildings    901244
#
# Unnamed: 3      1996     1997     1998     1999     2000     2001     2002  \
# Unnamed: 5   1431577  1712180  1954483  2052532  2235371  2102501  2029522
# ...

# %%
#Add column to a dataframe
df['building types by material'] = ['Timber residential buildings', 'Timber detached houses','Timber attached houses','Timber blocks of flats','Timber non-residential buildings', 'Non-timber residential buildings', 'Non-timber detached houses','Non-timber attached houses','Non-timber blocks of flats','Non-timber non-residential buildings']
df
# Out:
# Unnamed: 3      building material               Building type     1995  \
# Unnamed: 5        Wooden building       Residential buildings  1535633
# Unnamed: 7        Wooden building             Detached houses  1306540
# Unnamed: 9        Wooden building             Attached houses   207700
# Unnamed: 10       Wooden building             Blocks of flats    21393
# Unnamed: 16       Wooden building  Non-residential buildings   1486828
# Unnamed: 18  Non-wooden buildings       Residential buildings  1248319
# Unnamed: 19  Non-wooden buildings             Detached houses   149033
# Unnamed: 20  Non-wooden buildings             Attached houses   115110
# Unnamed: 21  Non-wooden buildings             Blocks of flats   984176
# Unnamed: 27  Non-wooden buildings  Non-residential buildings    901244
#
# Unnamed: 3      1996     1997     1998     1999     2000     2001     2002  \
# Unnamed: 5   1431577  1712180  1954483  2052532  2235371  2102501  2029522
# ...

# %%
df= df.set_index('building types by material')

# %%
df
# Out:
# Unnamed: 3                               building material  \
# building types by material
# Timber residential buildings               Wooden building
# Timber detached houses                     Wooden building
# Timber attached houses                     Wooden building
# Timber blocks of flats                     Wooden building
# Timber non-residential buildings           Wooden building
# Non-timber residential buildings      Non-wooden buildings
# Non-timber detached houses            Non-wooden buildings
# Non-timber attached houses            Non-wooden buildings
# Non-timber blocks of flats            Non-wooden buildings
# Non-timber non-residential buildings  Non-wooden buildings
#
# Unnamed: 3                                         Building type     1995  \
# building types by material
# Timber residential buildings               Residential buildings  1535633
# Timber detached houses                           Detached houses  1306540
# ...

# %%
df= df.drop(['building material','Building type'], axis= 1)
df
# Out:
# Unnamed: 3                               1995     1996     1997     1998  \
# building types by material
# Timber residential buildings          1535633  1431577  1712180  1954483
# Timber detached houses                1306540  1185993  1398407  1581016
# Timber attached houses                 207700   225757   287978   337246
# Timber blocks of flats                  21393    19827    25795    36221
# Timber non-residential buildings      1486828  1514347  1601728  1746293
# Non-timber residential buildings      1248319  1000560  1271486  1411431
# Non-timber detached houses             149033   132565   160819   190037
# Non-timber attached houses             115110   100203   120407   142690
# Non-timber blocks of flats             984176   767792   990260  1078704
# Non-timber non-residential buildings   901244  1084364  1208004  1487082
#
# Unnamed: 3                               1999     2000     2001     2002  \
# building types by material
# ...

# %%
df.astype(int)
# Out:
# Unnamed: 3                               1995     1996     1997     1998  \
# building types by material
# Timber residential buildings          1535633  1431577  1712180  1954483
# Timber detached houses                1306540  1185993  1398407  1581016
# Timber attached houses                 207700   225757   287978   337246
# Timber blocks of flats                  21393    19827    25795    36221
# Timber non-residential buildings      1486828  1514347  1601728  1746293
# Non-timber residential buildings      1248319  1000560  1271486  1411431
# Non-timber detached houses             149033   132565   160819   190037
# Non-timber attached houses             115110   100203   120407   142690
# Non-timber blocks of flats             984176   767792   990260  1078704
# Non-timber non-residential buildings   901244  1084364  1208004  1487082
#
# Unnamed: 3                               1999     2000     2001     2002  \
# building types by material
# ...

# %%
Timber_detached_and_attahed_houses = df.loc[['Timber detached houses', 'Timber attached houses']].sum()
Nontimber_detached_and_attahed_houses = df.loc[['Timber detached houses', 'Timber attached houses']].sum()

# %%
df.to_csv(r'C:\Users\nasirib2\OneDrive - Aalto University\Output.csv')

# %%
# Out:
#   File "<ipython-input-427-685c6fa57aa2>", line 1
#     df.to_excel(C:\Users\nasirib2\OneDrive - Aalto University\output.xlsx, index=True)
#                  ^
# SyntaxError: invalid syntax
